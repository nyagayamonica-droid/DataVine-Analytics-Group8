# %%
print("Hey Group8 Members, welcome to the project! Let's collaborate and make this project a success!")
# Out:
# Hey Group8 Members, welcome to the project! Let's collaborate and make this project a success!
